# %% [markdown]
# <a href="https://colab.research.google.com/github/PN1019/StockExchanges/blob/main/StockMarketDescriptiveStatics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing Modules**

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import pandas_datareader as DataReader
from datetime import date

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2edb3fa0-9f34-47c1-a149-3652cfb8b87c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2edb3fa0-9f34-47c1-a149-3652cfb8b87c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving nasdaq-listings.csv to nasdaq-listings.csv

# %%
# Import the data
nasdaq = pd.read_csv('nasdaq-listings.csv')

# Display first 10 rows
print(nasdaq.head(10))

# Inspect nasdaq
nasdaq.info()
# Out:
#   Stock Symbol  ... Last Update
# 0         AAPL  ...     4/26/17
# 1        GOOGL  ...     4/24/17
# 2         GOOG  ...     4/23/17
# 3         MSFT  ...     4/26/17
# 4         AMZN  ...     4/24/17
# 5           FB  ...     4/26/17
# 6        CMCSA  ...     4/26/17
# 7         INTC  ...     4/23/17
# 8         CSCO  ...     4/23/17
# 9         AMGN  ...     4/24/17
#
# [10 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Stock Symbol           1115 non-null   object
#  1   Company Name           1115 non-null   object
#  2   Last Sale              1115 non-null   float64
#  3   Market Capitalization  1115 non-null   float64
#  4   IPO Year               1115 non-null   object
#  5   Sector                 1115 non-null   object
#  6   Industry               1115 non-null   object
# ...

# %%
# Import the data
nasdaq = pd.read_csv('nasdaq-listings.csv', na_values='NAN', parse_dates=['Last Update'])

# Display the head of the data
print(nasdaq.head())

# Inspect the data
nasdaq.info()
# Out:
#   Stock Symbol  ... Last Update
# 0         AAPL  ...  2017-04-26
# 1        GOOGL  ...  2017-04-24
# 2         GOOG  ...  2017-04-23
# 3         MSFT  ...  2017-04-26
# 4         AMZN  ...  2017-04-24
#
# [5 rows x 8 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Stock Symbol           1115 non-null   object
#  1   Company Name           1115 non-null   object
#  2   Last Sale              1115 non-null   float64
#  3   Market Capitalization  1115 non-null   float64
#  4   IPO Year               593 non-null    float64
#  5   Sector                 1036 non-null   object
#  6   Industry               1036 non-null   object
#  7   Last Update            1115 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), object(4)
# memory usage: 69.8+ KB

# %% [markdown]
# Loading Lists From Single Sheet

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-20cafbf1-679d-4d51-aee4-60ef8f1bf05b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-20cafbf1-679d-4d51-aee4-60ef8f1bf05b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving listings.xlsx to listings.xlsx

# %%
# Import the data
nyse = pd.read_excel('listings.xlsx', sheet_name='nyse', na_values='n/a')

# Display the head of the data
print(nyse.head())

# Inspect the data
nyse.info()
# Out:
#   Stock Symbol  ...                                         Industry
# 0          DDD  ...          Computer Software: Prepackaged Software
# 1          MMM  ...                       Medical/Dental Instruments
# 2         WBAI  ...            Services-Misc. Amusement & Recreation
# 3         WUBA  ...  Computer Software: Programming, Data Processing
# 4          AHC  ...                             Newspapers/Magazines
#
# [5 rows x 7 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3147 entries, 0 to 3146
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Stock Symbol           3147 non-null   object
#  1   Company Name           3147 non-null   object
#  2   Last Sale              3079 non-null   float64
#  3   Market Capitalization  3147 non-null   float64
#  4   IPO Year               1361 non-null   float64
#  5   Sector                 2177 non-null   object
# ...

# %% [markdown]
# Load listing data from two sheets

# %%
# Create pd.ExcelFile() object
xls = pd.ExcelFile('listings.xlsx')

# Extract sheet names and store in exchanges
exchanges = xls.sheet_names

# Create listings dictionary with all sheet data
listings = pd.read_excel(xls, sheet_name=exchanges, na_values='n/a')

# Inspect NASDAQ listings
listings['nasdaq'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3167 entries, 0 to 3166
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Stock Symbol           3167 non-null   object
#  1   Company Name           3167 non-null   object
#  2   Last Sale              3165 non-null   float64
#  3   Market Capitalization  3167 non-null   float64
#  4   IPO Year               1386 non-null   float64
#  5   Sector                 2767 non-null   object
#  6   Industry               2767 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 173.3+ KB

# %% [markdown]
# Load all listing data and iterate over key-value dictionary pairs

# %%
# Import the NYSE and NASDAQ listings
nyse = pd.read_excel('listings.xlsx', sheet_name='nyse', na_values='n/a')
nasdaq = pd.read_excel('listings.xlsx', sheet_name='nasdaq', na_values='n/a')

# Inspect nyse and nasdaq
nyse.info()
nasdaq.info()

# Add Exchange reference columns
nyse['Exchange'] = 'NYSE'
nasdaq['Exchange'] = 'NASDAQ'

# Concatenate DataFrames  
combined_listings = pd.concat([nyse, nasdaq])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3147 entries, 0 to 3146
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Stock Symbol           3147 non-null   object
#  1   Company Name           3147 non-null   object
#  2   Last Sale              3079 non-null   float64
#  3   Market Capitalization  3147 non-null   float64
#  4   IPO Year               1361 non-null   float64
#  5   Sector                 2177 non-null   object
#  6   Industry               2177 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 172.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3167 entries, 0 to 3166
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Stock Symbol           3167 non-null   object
#  1   Company Name           3167 non-null   object
# ...

# %% [markdown]
# Automate the loading and combining of data from multiple Excel worksheets

# %%
# Create the pd.ExcelFile() object
xls = pd.ExcelFile('listings.xlsx')

# Extract the sheet names from xls
exchanges = xls.sheet_names

# Create an empty list: listings
listings = []

# Import the data
for exchange in exchanges:
    listing = pd.read_excel(xls, sheet_name=exchange, na_values='n/a')
    listing['Exchange'] = exchange
    listings.append(listing)

# Concatenate the listings: listing_data
listing_data = pd.concat(listings)

# Inspect the results
listing_data.info()
listing_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6674 entries, 0 to 3146
# Data columns (total 8 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Stock Symbol           6674 non-null   object
#  1   Company Name           6674 non-null   object
#  2   Last Sale              6590 non-null   float64
#  3   Market Capitalization  6674 non-null   float64
#  4   IPO Year               2852 non-null   float64
#  5   Sector                 5182 non-null   object
#  6   Industry               5182 non-null   object
#  7   Exchange               6674 non-null   object
# dtypes: float64(3), object(5)
# memory usage: 469.3+ KB
#      Stock Symbol  ... Exchange
# 0            XXII  ...     amex
# 1             FAX  ...     amex
# 2             IAF  ...     amex
# 3              CH  ...     amex
# 4  ABE             ...     amex
#
# [5 rows x 8 columns]

# %%
 pip install plotly

# %%
 pip install cufflinks

# %%
import cufflinks as cf
import plotly.graph_objs as go
import plotly as py #plotly
import plotly.express as px
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.subplots import make_subplots
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Get stock data for a single company
# Retrieving stock price data from Google Finance is simple after importing the DataReader package and using the start and/or end arguments in form date(YYYY, MM, DD):

# %%
from pandas_datareader.data import DataReader

from datetime import  date
series_code = 'DGS10' #10-year treasury rate
data_source = 'fred' # Fed Economic data Source

start = date(1962,1,1)
data_10 = DataReader(series_code,data_source,start)
data_10["Date"] =data_10.index
data_10.info()
data_10.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 15517 entries, 1962-01-02 to 2021-06-23
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DGS10   14855 non-null  float64
#  1   Date    15517 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 363.7 KB
#             DGS10       Date
# DATE
# 1962-01-02   4.06 1962-01-02
# 1962-01-03   4.03 1962-01-03
# 1962-01-04   3.99 1962-01-04
# 1962-01-05   4.02 1962-01-05
# 1962-01-08   4.03 1962-01-08

# %% [markdown]
# Plots

# %%
#plot 10 year treasury
fig = px.line(data_10, x="Date", y="DGS10", title='DGS10 Treasury Prices Trend Over The Last 50 Years')

fig.update_yaxes(title_text='10 Year Treasury(DGS10) Price') #Update Y-Axis title
fig.update_traces(line_color='#FF0000') #Update Chart color
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e7e80231-890b-49b4-b742-8eb8362d91d9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e7e80231-890b-49b4-b742-8eb8362d91d9")) {
#                     Plotly.newPlot(
#                         'e7e80231-890b-49b4-b742-8eb8362d91d9',
# ...

# %%
# Set start date
start = date(1968, 1, 1)

series = 'GOLDAMGBD228NLBM'

# Import the data
gold_price = DataReader(series, 'fred', start=start)
gold_price["Date"] =gold_price.index

# Inspect the price of gold
gold_price.info()
gold_price.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 13889 entries, 1968-04-01 to 2021-06-24
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   GOLDAMGBD228NLBM  13458 non-null  float64
#  1   Date              13889 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 325.5 KB
#             GOLDAMGBD228NLBM       Date
# DATE
# 1968-04-01              38.0 1968-04-01
# 1968-04-02              37.6 1968-04-02
# 1968-04-03              37.7 1968-04-03
# 1968-04-04              36.7 1968-04-04
# 1968-04-05              37.2 1968-04-05

# %%
#plotGold Treasury
fig = px.line(gold_price, x="Date", y="GOLDAMGBD228NLBM", title='Gold Prices Trend Over The Last 50 Years')

fig.update_yaxes(title_text='Gold Price') #Update Y-Axis title
fig.update_traces(line_color='#FF0000') #Update Chart color
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b3d5e185-16e8-4cbe-9e58-14c4210cee76" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b3d5e185-16e8-4cbe-9e58-14c4210cee76")) {
#                     Plotly.newPlot(
#                         'b3d5e185-16e8-4cbe-9e58-14c4210cee76',
# ...

# %% [markdown]
# ### Compare labor market participation and unemployment rates
#
#
# Two economic data series in FRED are the Civilian Unemployment Rate ('UNRATE') and the Civilian Labor Force Participation Rate ('CIVPART').
#
# These rates highlight two important aspects of the US labor market: the share of the civilian population that is currently unemployed or seeking employment, and the share of those active in the labor market that are in fact employed.
#
# This means that the numbers indicate both the size of the labor market relative to the total population, as well as the size of unemployment relative to the labor market.

# %%
# Set the start date
start = date(1950, 1, 1)

# Define the series code
series = ['UNRATE', 'CIVPART']

# Import the data
econ_data = DataReader(series, 'fred', start)

# Assign new column labels
econ_data.columns = ['Unemployment Rate', 'Participation Rate']
econ_data['Date']=econ_data.index
econ_data.info()
econ_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 857 entries, 1950-01-01 to 2021-05-01
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unemployment Rate   857 non-null    float64
#  1   Participation Rate  857 non-null    float64
#  2   Date                857 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 26.8 KB
#             Unemployment Rate  Participation Rate       Date
# DATE
# 1950-01-01                6.5                58.9 1950-01-01
# 1950-02-01                6.4                58.9 1950-02-01
# 1950-03-01                6.3                58.8 1950-03-01
# 1950-04-01                5.8                59.2 1950-04-01
# 1950-05-01                5.5                59.1 1950-05-01

# %%
#Comprision chart for Unemployment and participation in Labour Market
fig = make_subplots(
    rows=2, cols=1,
    shared_xaxes=True,
    vertical_spacing=0.03,
    specs=[[{"type": "scatter"}],
           [{"type": "scatter"}]]
)

fig.add_trace(
    go.Scatter(
        x=econ_data["Date"],
        y=econ_data["Unemployment Rate"],
        mode="lines",
        name="Unemployement Rate"
    ),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(
        x=econ_data["Date"],
        y=econ_data["Participation Rate"],
        mode="lines",
        name="Participation Rate"
    ),
    row=2, col=1
)

fig.update_layout(
    height=800,
    showlegend=False,
    title_text="Comparision For Unemployment And Participation Rate In Labour Market ",
)

#fig = px.line(econ_data,x="Date",y=econ_data.columns,title="Comparision in Labour Market")
fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="e86b5012-fc09-48e2-9791-4c3021d1e7b7" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e86b5012-fc09-48e2-9791-4c3021d1e7b7")) {
#                     Plotly.newPlot(
#                         'e86b5012-fc09-48e2-9791-4c3021d1e7b7',
# ...

# %% [markdown]
# ### Compare bond and stock performance
# Bonds and stocks are the most important investment alternatives. Now that you can import data from both the Federal Reserve and Google Finance, you can compare the performance of both asset classes. You'll be using a Total Return Index for each class, which accounts for returns due to both price increases and payments like interest or dividends.
#
# For bonds, you'll use the Bank of America Merrill Lynch US High Yield Total Return Index Value ('BAMLHYH0A0HYM2TRIV'). For stocks, you'll use the S&P 500 Index ('SP500'). Both are available for the past 10 years from the Federal Reserve's FRED service.

# %%
# Set the start date
start = date(2008, 1, 1)

# Set the series code
series = ['BAMLHYH0A0HYM2TRIV', 'SP500']

# Import the data
inv_data = DataReader(series, 'fred', start)
inv_data['Date']=inv_data.index
inv_data.info()
inv_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3564 entries, 2008-01-01 to 2021-06-24
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BAMLHYH0A0HYM2TRIV  3520 non-null   float64
#  1   SP500               2516 non-null   float64
#  2   Date                3564 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 111.4 KB
#             BAMLHYH0A0HYM2TRIV  SP500       Date
# DATE
# 2008-01-01                 NaN    NaN 2008-01-01
# 2008-01-02              590.74    NaN 2008-01-02
# 2008-01-03              589.02    NaN 2008-01-03
# 2008-01-04              586.38    NaN 2008-01-04
# 2008-01-07              584.90    NaN 2008-01-07

# %%
#Performance Comparision chart 
fig = make_subplots(
    rows=2, cols=1,
    shared_xaxes=True,
    vertical_spacing=0.03,
    specs=[[{"type": "scatter"}],
           [{"type": "scatter"}]]
)

fig.add_trace(
    go.Scatter(
        x=inv_data["Date"],
        y=inv_data["BAMLHYH0A0HYM2TRIV"],
        mode="lines",
        name="BOA Bonds Return Index"
    ),
    row=1, col=1
)

fig.add_trace(
    go.Scatter(
        x=inv_data["Date"],
        y=inv_data["SP500"],
        mode="lines",
        name="S&P 500 Index Return Rate"
    ),
    row=2, col=1
)

fig.update_layout(
    height=800,
    showlegend=False,
    title_text="Performance Comparision Of Bonds And Stocks Return Rate ",
)

fig.show(renderer="colab")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="ff1ec35f-f087-42a9-8689-3606926ec4b3" class="plotly-graph-div" style="height:800px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ff1ec35f-f087-42a9-8689-3606926ec4b3")) {
#                     Plotly.newPlot(
#                         'ff1ec35f-f087-42a9-8689-3606926ec4b3',
# ...

# %% [markdown]
# ### Top 5 listed Company in Market Capitalization

# %%
nyse = nyse.sort_values('Market Capitalization', ascending=False)
nyse[['Stock Symbol', 'Company Name']].head()
# Out:
#      Stock Symbol                   Company Name
# 1586          JNJ              Johnson & Johnson
# 1125          XOM        Exxon Mobil Corporation
# 1548          JPM          J P Morgan Chase & Co
# 80           BABA  Alibaba Group Holding Limited
# 1280           GE       General Electric Company

# %% [markdown]
# ###  Listing Technology Companies

# %%
tech = nyse.loc[nyse.Sector=='Technology']
tech['Company Name'].head(5)
# Out:
# 2144                                 Oracle Corporation
# 2692    Taiwan Semiconductor Manufacturing Company Ltd.
# 1499        International Business Machines Corporation
# 2488                                             SAP SE
# 2031                                    NTT DOCOMO, Inc
# Name: Company Name, dtype: object

# %%
nyse.loc[nyse.Sector=='Technology','Market Capitalization'].idxmax()
# Out:
# 2144

# %% [markdown]
# ### Top 5 Consumer Companies

# %%
# Select companies in Consumer Services
consumer_services = listing_data[listing_data.Sector == 'Consumer Services']

# Sort consumer_services by market cap
consumer_services2 = consumer_services.sort_values('Market Capitalization', ascending=False)

# Display first 5 rows of designated columns
print(consumer_services2[['Company Name', 'Exchange', 'Market Capitalization']].head())
# Out:
#                    Company Name Exchange  Market Capitalization
# 4              Amazon.com, Inc.   nasdaq           4.221385e+11
# 3013      Wal-Mart Stores, Inc.     nyse           2.218646e+11
# 3014  Walt Disney Company (The)     nyse           1.789973e+11
# 6           Comcast Corporation   nasdaq           1.764745e+11
# 1438     Home Depot, Inc. (The)     nyse           1.752626e+11
